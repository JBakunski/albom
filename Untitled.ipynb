# %%
import pandas as pd

# %%
data = pd.read_html('https://www.officialcharts.com/chart-news/the-best-selling-albums-of-all-time-on-the-official-uk-chart__15551/', header=0)

# %%
df = data[0]

# %%
df.head()
# Out:
#    POS                                 TITLE   ARTIST  YEAR  HIGH POSN
# 0    1                         GREATEST HITS    QUEEN  1981          1
# 1    2                  GOLD - GREATEST HITS     ABBA  1992          1
# 2    3  SGT PEPPER'S LONELY HEARTS CLUB BAND  BEATLES  1967          1
# 3    4                                    21    ADELE  2011          1
# 4    5        WHAT'S THE STORY MORNING GLORY    OASIS  1995          1

# %% [markdown]
# ### Change columns name

# %%
df.rename(columns={'POS': 'POZ', 'TITLE': 'TYTUŁ', 'ARTIST': 'ARTYSTA', 'YEAR': 'ROK', 'HIGH POSN': 'MAX POZ'}, inplace=True)

# %% [markdown]
# ### Number of artists in the album

# %%
df['ARTYSTA'].nunique()
# Out:
# 47

# %%
df['ARTYSTA'].value_counts().head(5)
# Out:
# COLDPLAY         3
# TAKE THAT        3
# FLEETWOOD MAC    2
# ABBA             2
# DIDO             2
# Name: ARTYSTA, dtype: int64

# %%
df.rename(str.capitalize, axis=1, inplace=True)

# %%
df.head()
# Out:
#    Poz                                 Tytuł  Artysta   Rok  Max poz
# 0    1                         GREATEST HITS    QUEEN  1981        1
# 1    2                  GOLD - GREATEST HITS     ABBA  1992        1
# 2    3  SGT PEPPER'S LONELY HEARTS CLUB BAND  BEATLES  1967        1
# 3    4                                    21    ADELE  2011        1
# 4    5        WHAT'S THE STORY MORNING GLORY    OASIS  1995        1

# %%
df.drop('Max poz', axis=1)
# Out:
#     Poz                                   Tytuł                   Artysta  \
# 0     1                           GREATEST HITS                     QUEEN
# 1     2                    GOLD - GREATEST HITS                      ABBA
# 2     3    SGT PEPPER'S LONELY HEARTS CLUB BAND                   BEATLES
# 3     4                                      21                     ADELE
# 4     5          WHAT'S THE STORY MORNING GLORY                     OASIS
# 5     6                                THRILLER           MICHAEL JACKSON
# 6     7               THE DARK SIDE OF THE MOON                PINK FLOYD
# 7     8                        BROTHERS IN ARMS              DIRE STRAITS
# 8     9                                     BAD           MICHAEL JACKSON
# 9    10                        GREATEST HITS II                     QUEEN
# 10   11                                 RUMOURS             FLEETWOOD MAC
# 11   12               THE IMMACULATE COLLECTION                   MADONNA
# ...

# %%
df.set_index('Rok', inplace=True)

# %%
df.groupby(by='Tytuł', level='Rok').count().sort_values(by='Tytuł', ascending=False).head()
# Out:
#       Poz  Tytuł  Artysta  Max poz
# Rok
# 2000    4      4        4        4
# 1987    4      4        4        4
# 1998    3      3        3        3
# 2006    3      3        3        3
# 1997    3      3        3        3

# %%
df.reset_index(inplace=True)

# %%
albums_in_years = df[(df['Rok']>1960) & (df['Rok'] <= 1990)]
albums_in_years['Tytuł'].count()
# Out:
# 22

# %%
df['Rok'].min()
# Out:
# 1965

# %%
df.sort_values(by=['Artysta', 'Rok']).drop_duplicates(subset='Artysta', keep='first', inplace=True)

# %%
df
# Out:
#      Rok  Poz                                   Tytuł  \
# 0   1981    1                           GREATEST HITS
# 1   1992    2                    GOLD - GREATEST HITS
# 2   1967    3    SGT PEPPER'S LONELY HEARTS CLUB BAND
# 3   2011    4                                      21
# 4   1995    5          WHAT'S THE STORY MORNING GLORY
# 5   1982    6                                THRILLER
# 6   1973    7               THE DARK SIDE OF THE MOON
# 7   1985    8                        BROTHERS IN ARMS
# 8   1987    9                                     BAD
# 9   1991   10                        GREATEST HITS II
# 10  1977   11                                 RUMOURS
# 11  1990   12               THE IMMACULATE COLLECTION
# 12  2006   13                           BACK TO BLACK
# 13  1991   14                                   STARS
# 14  1997   15                            COME ON OVER
# 15  1984   16                                  LEGEND
# ...
